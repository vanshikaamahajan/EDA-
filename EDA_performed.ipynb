# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshikaamahajan/EDA-/blob/main/EDA_performed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data=pd.read_csv('/content/archive.zip')
Data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
Data.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
Data=Data.drop(['salary_currency','salary_in_usd'],axis=1)
Data.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary employee_residence  remote_ratio company_location company_size
# 0   80000                 ES           100               ES            L
# 1   30000                 US           100               US            S
# 2   25500                 US           100               US            S
# 3  175000                 CA           100               CA            M
# 4  120000                 CA           100               CA            M

# %%
Data.rename(columns={'work_year':'YEAR','remote_ratio':'RATIO','experience_level':'EXPERIENCE','salary':'SALARY','company_size':'COMPANY SIZE'})
# Out:
#       YEAR EXPERIENCE employment_type                 job_title   SALARY  \
# 0     2023         SE              FT  Principal Data Scientist    80000
# 1     2023         MI              CT               ML Engineer    30000
# 2     2023         MI              CT               ML Engineer    25500
# 3     2023         SE              FT            Data Scientist   175000
# 4     2023         SE              FT            Data Scientist   120000
# ...    ...        ...             ...                       ...      ...
# 3750  2020         SE              FT            Data Scientist   412000
# 3751  2021         MI              FT  Principal Data Scientist   151000
# 3752  2020         EN              FT            Data Scientist   105000
# 3753  2020         EN              CT     Business Data Analyst   100000
# 3754  2021         SE              FT      Data Science Manager  7000000
#
#      employee_residence  RATIO company_location COMPANY SIZE
# ...

# %%
duplicate_rows_Data=Data[Data.duplicated()]
print('No. of duplicate rows : ',duplicate_rows_Data.shape)
# Out:
# No. of duplicate rows :  (1171, 9)

# %%
Data.count()
# Out:
# work_year             3755
# experience_level      3755
# employment_type       3755
# job_title             3755
# salary                3755
# employee_residence    3755
# remote_ratio          3755
# company_location      3755
# company_size          3755
# dtype: int64

# %%
Data=Data.drop_duplicates()
Data.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary employee_residence  remote_ratio company_location company_size
# 0   80000                 ES           100               ES            L
# 1   30000                 US           100               US            S
# 2   25500                 US           100               US            S
# 3  175000                 CA           100               CA            M
# 4  120000                 CA           100               CA            M

# %%
Data.count()
# Out:
# work_year             2584
# experience_level      2584
# employment_type       2584
# job_title             2584
# salary                2584
# employee_residence    2584
# remote_ratio          2584
# company_location      2584
# company_size          2584
# dtype: int64

# %%
print(Data.isnull().sum())
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
Data=Data.dropna()
Data.count()
# Out:
# work_year             2584
# experience_level      2584
# employment_type       2584
# job_title             2584
# salary                2584
# employee_residence    2584
# remote_ratio          2584
# company_location      2584
# company_size          2584
# dtype: int64

# %%
sns.boxplot(x=Data['salary'])
# Out:
# <Axes: xlabel='salary'>

# %%
sns.boxplot(x=Data['remote_ratio'])
# Out:
# <Axes: xlabel='remote_ratio'>

# %%
plt.figure(figsize=(8,5))
c=Data.corr()
sns.heatmap(c,annot=True)
# Out:
# <ipython-input-54-784a264e6d97>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=Data.corr()
# <Axes: >
